# %% [markdown]
# # Project     : dsfpt10-p1-dsc-phase-1-project
# ## date        : 09-02-2025
# ## author      : Brian Waweru

# %%
import pandas as pd
import numpy as numpy

print('import successful!')
# Out:
# import successful!

# %% [markdown]
# ### Loading the data

# %%
# File path
file_path = 'data/AviationData.csv'

# Read the CSV with ISO-8859-1 encoding
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# display the first 3 entries
df.head(3)
# Out:
# c:\Users\rurig\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (6,7,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
#
#           Location        Country Latitude Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States      NaN       NaN          NaN
# 1   BRIDGEPORT, CA  United States      NaN       NaN          NaN
# 2    Saltville, VA  United States  36.9222  -81.8781          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
# (6,7,28)

col_check = df.iloc[:, [6, 7, 28]]
col_check.head()#info()
# Out:
#   Latitude Longitude Broad.phase.of.flight
# 0      NaN       NaN                Cruise
# 1      NaN       NaN               Unknown
# 2  36.9222  -81.8781                Cruise
# 3      NaN       NaN                Cruise
# 4      NaN       NaN              Approach

# %%
print(len(df.columns))
print()

df.columns
# Out:
# 31
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
df.shape
# Out:
# (88889, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50249 non-null  object
#  9   Airport.Name            52790 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87572 non-null  object
# ...

# %%
df['Event.Id'].count() # 88889

df['Event.Id'].nunique()

print(88889 - 87951)
# Out:
# 938

# %%
# df[df.duplicated()]
df[df.duplicated(subset=['Event.Id'])]#['Event.Id'].count()
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 118    20020917X01908           Accident     DCA82AA012A  1982-01-19
# 159    20020917X02400           Accident     MIA82FA038A  1982-01-23
# 160    20020917X02259           Accident     LAX82FA049B  1982-01-23
# 245    20020917X02585           Accident     SEA82DA028B  1982-02-06
# 248    20020917X02173           Accident     LAX82DA065A  1982-02-06
# ...               ...                ...             ...         ...
# 88593  20220929106019           Accident      DCA22WA214  2022-09-28
# 88777  20221112106276           Accident      CEN23MA034  2022-11-12
# 88796  20221121106336           Accident      WPR23LA041  2022-11-18
# 88798  20221122106340           Incident      DCA23WA071  2022-11-18
# 88814  20221123106354           Accident      WPR23LA045  2022-11-22
#
#                  Location        Country Latitude Longitude Airport.Code  \
# ...

# %%
df.loc[df.duplicated(subset='Event.Id'
                    #  ,keep=False
                     )
                     ]['Event.Id']#.count()# == True]['Event.Id']#.nunique()
# Out:
# 118      20020917X01908
# 159      20020917X02400
# 160      20020917X02259
# 245      20020917X02585
# 248      20020917X02173
#               ...
# 88593    20220929106019
# 88777    20221112106276
# 88796    20221121106336
# 88798    20221122106340
# 88814    20221123106354
# Name: Event.Id, Length: 938, dtype: object

# %%
data = df.loc[df['Event.Id'] == '20221121106336']#.duplicated()
data.duplicated()#subset='Location')

cols = data.columns.tolist()
for item in cols:
    print(data.duplicated(subset=item))
    print()
# Out:
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796    False
# dtype: bool
#
# 88795    False
# 88796    False
# dtype: bool
#
# 88795    False
# 88796    False
# dtype: bool
#
# 88795    False
# 88796    False
# dtype: bool
#
# 88795    False
# 88796    False
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# 88795    False
# 88796     True
# dtype: bool
#
# ...

# %%
df = df.drop_duplicates(subset=['Event.Id'])

# %%
df['Investigation.Type'].unique()
# Out:
# array(['Accident', 'Incident'], dtype=object)

# %%
df['Investigation.Type'].value_counts().to_frame()#|.sum()
# Out:
#           Investigation.Type
# Accident               85015
# Incident                3874
